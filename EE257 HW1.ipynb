# %%
#show current directory
# %pwd
# Out:
# 'c:\\Users\\tickn\\ml\\EE257'

# %%
## Read the csv file
import pandas as pd 
dataset = pd.read_csv('mcs_ds_edited_iter_shuffled.csv')

# %%
#show first few rows of datafile
dataset.head()
# Out:
#    anchor_ratio  trans_range  node_density  iterations       ale    sd_ale
# 0            30           15           200          40  0.773546  0.250555
# 1            15           15           100          70  0.911941  0.498329
# 2            30           15           100          50  0.814867  0.255546
# 3            15           20           100          20  1.435332  0.394603
# 4            30           15           100          40  1.265909  0.302943

# %%
#display data from a column
dataset["anchor_ratio"]
# Out:
# 0      30
# 1      15
# 2      30
# 3      15
# 4      30
#        ..
# 102    18
# 103    14
# 104    15
# 105    20
# 106    15
# Name: anchor_ratio, Length: 107, dtype: int64

# %%
# get summary statistics of dataset
dataset.describe()
# Out:
#        anchor_ratio  trans_range  node_density  iterations         ale  \
# count    107.000000   107.000000    107.000000  107.000000  107.000000
# mean      20.523364    17.878505    159.813084   47.887850    0.983471
# std        6.739556     3.107235     71.189109   24.668874    0.408313
# min       10.000000    12.000000    100.000000   14.000000    0.394029
# 25%       15.000000    15.000000    100.000000   30.000000    0.655368
# 50%       18.000000    17.000000    100.000000   40.000000    0.899102
# 75%       30.000000    20.000000    200.000000   70.000000    1.196418
# max       30.000000    25.000000    300.000000  100.000000    2.568407
#
#            sd_ale
# count  107.000000
# mean     0.265692
# std      0.183394
# min      0.003267
# 25%      0.128437
# 50%      0.242423
# 75%      0.362762
# max      1.092220

# %%
#plot histogram of dataset
# %matplotlib inline
import matplotlib.pyplot as plt
dataset.hist(bins = 10, figsize=(20,15))
plt.show()

# %%
#box plot for a column
dataset.boxplot(column=["trans_range"])
# Out:
# <AxesSubplot:>

# %%
#scatter plot
dataset.plot(kind="scatter", x="anchor_ratio", y="trans_range")
# Out:
# <AxesSubplot:xlabel='anchor_ratio', ylabel='trans_range'>

# %%
#correlation matrix
corr_matrix = dataset.corr()

#show correlation with other features descending order
corr_matrix["anchor_ratio"].sort_values(ascending=False)
# Out:
# anchor_ratio    1.000000
# iterations      0.023167
# ale            -0.074997
# trans_range    -0.094692
# sd_ale         -0.104657
# node_density   -0.116986
# Name: anchor_ratio, dtype: float64

# %%
#scatter matrix
from pandas.plotting import scatter_matrix
scatter_matrix(dataset,figsize=(20,15))
# Out:
# array([[<AxesSubplot:xlabel='anchor_ratio', ylabel='anchor_ratio'>,
#         <AxesSubplot:xlabel='trans_range', ylabel='anchor_ratio'>,
#         <AxesSubplot:xlabel='node_density', ylabel='anchor_ratio'>,
#         <AxesSubplot:xlabel='iterations', ylabel='anchor_ratio'>,
#         <AxesSubplot:xlabel='ale', ylabel='anchor_ratio'>,
#         <AxesSubplot:xlabel='sd_ale', ylabel='anchor_ratio'>],
#        [<AxesSubplot:xlabel='anchor_ratio', ylabel='trans_range'>,
#         <AxesSubplot:xlabel='trans_range', ylabel='trans_range'>,
#         <AxesSubplot:xlabel='node_density', ylabel='trans_range'>,
#         <AxesSubplot:xlabel='iterations', ylabel='trans_range'>,
#         <AxesSubplot:xlabel='ale', ylabel='trans_range'>,
#         <AxesSubplot:xlabel='sd_ale', ylabel='trans_range'>],
#        [<AxesSubplot:xlabel='anchor_ratio', ylabel='node_density'>,
#         <AxesSubplot:xlabel='trans_range', ylabel='node_density'>,
# ...
